# %% [markdown]
# ##### `open()` 函式
# |`"r"`|`"a"`|`"w"`|`"x"`|`"t"`|`"b"`|
# |:--:|:--:|:--:|:--:|:--:|:--:|
# |read|append|write|create|text|binary|

# %% [markdown]
# ##### 讀取檔案 read( )

# %%
# 印出 50 個 "="

print('='*50)
# 讀取檔案內容 - 常用的寫法 (執行完畢會自動關閉檔案)
with open(file='../Module2/2-1.py', mode= 'r' , encoding = 'utf-8') as f:
    texts = f.read()
print(texts)

# 印出 50 個 "="
print('='*50)
# Out:
# ==================================================
# # 建立第一支 Python 程式
#
# # 宣告變數
# name = "Harry"
#
#
#
# # 輸出變數
# print(name)
#
#
# ==================================================

# %%
# 一行一行讀取 把每一行放進 list
with open(file="../Module2/2-1.py", mode='r', encoding="utf-8") as f:
    text = f.readlines()
print(text)
# Out:
# ['# 建立第一支 Python 程式\n', '\n', '# 宣告變數\n', 'name = "Harry"\n', '\n', '\n', '\n', '# 輸出變數\n', 'print(name)\n', '\n']

# %%
# 資料處理
result = []

for text in texts:
    if text =='\n':
        continue
    result.append(text.strip('\n'))

print(result)
# Out:
# ['#', ' ', '建', '立', '第', '一', '支', ' ', 'P', 'y', 't', 'h', 'o', 'n', ' ', '程', '式', '#', ' ', '宣', '告', '變', '數', 'n', 'a', 'm', 'e', ' ', '=', ' ', '"', 'H', 'a', 'r', 'r', 'y', '"', '#', ' ', '輸', '出', '變', '數', 'p', 'r', 'i', 'n', 't', '(', 'n', 'a', 'm', 'e', ')']

# %% [markdown]
# ##### 寫入檔案 write( )

# %%
# 文字內容
text = '''
傑出的人會努力規劃自己的人生，普通的人則是隨便命運怎麼安排   
一個是充實、有目的的過每一天，一個是隨興的過一天算一天
創業這條路 Michael E.Gerber
'''

# 寫入檔案
with open('file.txt', 'w', encoding='utf-8') as f:
    f.write(text)

# %%
# 寫入資料到最後一行 (附加文字在檔案內容最後一行)
texts = "people say that success just happens to you. it doesn't!"
with open('file.txt', 'a', encoding='utf-8') as f:
    f.write(texts+'\n')

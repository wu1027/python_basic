# %% [markdown]
# 百貨公司周年慶 消費金額超過 2000 要折 200
#
# 請撰寫一支程式
# 計算客戶消費的結帳金額

# %%
score = 4300
if score >= 2000:
    score = score - 200 


print("最後價格")
print(score)
# Out:
# 最後價格
# 4100

# %%
total = 3900

if total >= 2000 :
    cnt = total // 2000
    print(cnt)
    total -= 200*cnt

print(total)
# Out:
# 1
# 3700

# %%
total = 6000

print(total - (total//2000)*200)
# Out:
# 5400

# %% [markdown]
# |基本型態|創建方式|
# |:---:|:---:|
# | int | num = 10 |
# | float | num = 2.5 |
# | boolean |  |
# | string |  |

# %% [markdown]
# |容器型態|創建方式|
# |:---:|:---:|
# |list| | |
# |tuple||
# |set||
# |dict||

# %% [markdown]
# 整數 (int)、浮點數 (float)

# %%
print

# %% [markdown]
# 布林值 (boolean)

# %%
parse_ok = True
parse_not_ok = False

print(parse_ok)
print(parse_not_ok)
print(type(parse_not_ok))
# Out:
# True
# False
# <class 'bool'>

# %% [markdown]
# 字串 (string)

# %%
name = "Harry"
print(name)
# Out:
# Harry

# %%
data = "False"
print(data)
#檢查資料型態
print(type(data))
# Out:
# False
# <class 'str'>

# %% [markdown]
# 列表 (list)

# %%
data="False"
print(data)
# Out:
# False

# %%
num_list = [1, 2, 3,]
print(num_list)
print(type(num_list))
# Out:
# [1, 2, 3]
# <class 'list'>

# %% [markdown]
# 元組 (tuple)

# %%
num_tuple = (1, 2, 3,)
print(num_tuple)
print(type(num_tuple))
# Out:
# (1, 2, 3)
# <class 'tuple'>

# %% [markdown]
# 集合 (set)

# %%
num_set = {1, 2, 3,3}
print(num_set)#set不會有重複的值
# Out:
# {1, 2, 3}

# %% [markdown]
# 字典 (dict)

# %%
user_info = {"name": "harry", "age": 26}
print(user_info)
print(type(user_info))
# Out:
# {'name': 'harry', 'age': 26}
# <class 'dict'>

# %%
#空的list
result = []
print(result)
print(type(result))
# Out:
# []
# <class 'list'>

# %%
# 創建一個空的 dict
result = {}
print(result)
print(type(result))

# %%
# 創建一個空的 set
empty_set

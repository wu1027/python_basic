# %%
# 自訂例外處理
toral = -100

if total < 0:
    raise ValueError('金額不能小於 0')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 # 自訂例外處理
#       2 toral = -100
#       3
# ----> 4 if total < 0:
#       5     raise ValueError('金額不能小於 0')
#
# NameError: name 'total' is not defined

# %%
# 自訂型別錯誤(TypeError)的例外處理
file = 'python.pdf'

print(file[-3:])
if file[-3:].lower() != 'pdf':
    raise TypeError('僅能上傳 pdf')
# Out:
# pdf

# %% [markdown]
# ##### 設計 raise 陳述

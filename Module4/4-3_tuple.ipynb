# %%
# tuple 初始化: 第一種
data = ("Alex", "Allen")
print(data)
print(type(data))
# Out:
# ('Alex', 'Allen')
# <class 'tuple'>

# %%
# tuple 初始化: 第二種
data = "Alex", "Allen", "Alice"
print(data)
print(type(data))
# Out:
# ('Alex', 'Allen', 'Alice')
# <class 'tuple'>

# %%
# 透過指定索引輸出值
data = ("Alex", "Allen")
print(data[0])
# Out:
# Alex

# %%
name, age = ("Alex", 30)
print(name)
print(age)
# Out:
# Alex
# 30

# %%
name, age = "Alex", 30
print(name)
print(age)
# Out:
# Alex
# 30

# %%
# 複數變數修改值

# %%
# tuple 不可以修改指定索引的值
data
# Out:
# ('Alex', 'Allen')

# %%
# ( )可以修改指定索引的值

# %%
# 用 for 迴圈逐一輸出資料
data = (1, 2, 3)
for i in data:
    print(i)
# Out:
# 1
# 2
# 3

# %%
# 用 len 計算 tuple 資料個數
data = (1, 2, 3)
print(len(data))
# Out:
# 3

# %% [markdown]
# 條件語句 if-elif-else

# %%
'''
條件判斷
if ...
if ... else ...
if ... elif ... else ...

'''

# %% [markdown]
# ##### if

# %%
age = 25

if age == 25:
    
    print("條件成立")
# Out:
# 條件成立

# %% [markdown]
# ##### if...else...

# %%
score = 50

if score >= 60:
    print("及格")
else: #if敘述為false就執行else
    print("不及格")
# Out:
# 不及格

# %% [markdown]
# ##### if...elif... (else)

# %%
score = 95

if score == 100:
    print("滿分!")
elif score >= 90:
    print("優等")
elif score >= 60:
    print("及格")
else:
    print("不及格")
# Out:
# 優等

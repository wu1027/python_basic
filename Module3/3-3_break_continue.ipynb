# %% [markdown]
# ##### break

# %%
'''
當偵測到字母 t 時，就會強制結束迴圈
'''
for char in "contents":
    print(char)
    if char =="t":
        print("遇到字母 t 結束整個迴圈")
        break
# Out:
# c
# o
# n
# t
# 遇到字母 t 結束整個迴圈

# %% [markdown]
# ##### continue

# %%
'''
當偵測到字母 t 時，
會跳過本次迴圈剩下的程式碼 print(char)，
但不會結束迴圈，仍然會進入下一圈繼續執行
'''
for char in "contents":
    
    if char =="t":

        print("遇到字母 t 跳過 continue 以下程式碼 進行下一次迴圈")
        continue
    print(char)
# Out:
# c
# o
# n
# 遇到字母 t 跳過 continue 以下程式碼 進行下一次迴圈
# e
# n
# 遇到字母 t 跳過 continue 以下程式碼 進行下一次迴圈
# s

# %% [markdown]
# ### 小試身手
# 計算 1 到 100 之間的和，如果值超過500就停止執行

# %%
total = 0
for i in range(1, 101):
    total += i
    if total >=500:
        break
    #print(i, end+", ")

print(total)
# Out:
# 528

# %% [markdown]
# 計算 1 到 100 之間的奇數之和，但要跳過所有被 5 整除的數

# %%
total = 0

for i in range(1, 101):
    if i % 2 == 0 or i % 5 == 0:
        continue
    total += i
    #print(i, end=", ")

    
print(total)
# Out:
# 2000

# %%
total = 0
for i in range(1, 101, 2):
    if i % 5 == 0:
        continue
    total += i

print(total)
# Out:
# 2000
